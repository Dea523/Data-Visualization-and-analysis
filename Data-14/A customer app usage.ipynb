# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv("customers.csv")

# %%
df
# Out:
#           id  gender  age  number_of_kids
# 0     979863    MALE   26               2
# 1     780123    MALE   60               2
# 2     614848    MALE   45               4
# 3     775046    MALE   62               3
# 4     991601    MALE   23               0
# ...      ...     ...  ...             ...
# 2495  208889  FEMALE   18               0
# 2496  385802  FEMALE   25               0
# 2497  990291    MALE   71               0
# 2498  285058    MALE   28               4
# 2499  165666    MALE   35               1
#
# [2500 rows x 4 columns]

# %%
df.head()
# Out:
#        id gender  age  number_of_kids
# 0  979863   MALE   26               2
# 1  780123   MALE   60               2
# 2  614848   MALE   45               4
# 3  775046   MALE   62               3
# 4  991601   MALE   23               0

# %%
df.tail()
# Out:
#           id  gender  age  number_of_kids
# 2495  208889  FEMALE   18               0
# 2496  385802  FEMALE   25               0
# 2497  990291    MALE   71               0
# 2498  285058    MALE   28               4
# 2499  165666    MALE   35               1

# %%
df.shape
# Out:
# (2500, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2500 non-null   int64
#  1   gender          2500 non-null   object
#  2   age             2500 non-null   int64
#  3   number_of_kids  2500 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#                   id          age  number_of_kids
# count    2500.000000  2500.000000     2500.000000
# mean   562397.047200    35.922400        1.395200
# std    256410.208166    14.171207        1.505697
# min    111556.000000    18.000000        0.000000
# 25%    343199.000000    25.000000        0.000000
# 50%    563854.500000    31.000000        1.000000
# 75%    787978.750000    45.000000        3.000000
# max    998740.000000    75.000000        4.000000

# %%
df.isnull()
# Out:
#          id  gender    age  number_of_kids
# 0     False   False  False           False
# 1     False   False  False           False
# 2     False   False  False           False
# 3     False   False  False           False
# 4     False   False  False           False
# ...     ...     ...    ...             ...
# 2495  False   False  False           False
# 2496  False   False  False           False
# 2497  False   False  False           False
# 2498  False   False  False           False
# 2499  False   False  False           False
#
# [2500 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# id                0
# gender            0
# age               0
# number_of_kids    0
# dtype: int64

# %%
df.nunique()
# Out:
# id                2497
# gender               2
# age                 58
# number_of_kids       5
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'number_of_kids'], dtype='object')

# %%
px.pie(df, names='gender', title='gender')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# Length: 2500, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#info
df['gender'].value_counts(normalize=True) * 100
# Out:
# MALE      75.76
# FEMALE    24.24
# Name: gender, dtype: float64

# %%
#info
df['number_of_kids'].value_counts(normalize=True) * 100
# Out:
# 0    44.48
# 3    14.28
# 4    14.20
# 1    14.20
# 2    12.84
# Name: number_of_kids, dtype: float64

# %%
sns.boxplot( data=df, x='age', y='number_of_kids')
# Out:
# <AxesSubplot: xlabel='age', ylabel='number_of_kids'>

# %%
sns.pairplot(df, hue='age')

# %%
sns.pairplot(df, hue='gender')

# %%
sns.scatterplot(data=df, x='age', y='number_of_kids')
# Out:
# <AxesSubplot: xlabel='age', ylabel='number_of_kids'>

# %%
df.sample()
# Out:
#          id  gender  age  number_of_kids
# 877  631635  FEMALE   44               2

# %%
df.isnull().any()
# Out:
# id                False
# gender            False
# age               False
# number_of_kids    False
# dtype: bool

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'number_of_kids'], dtype='object')

# %%
df['number_of_kids'].mode()
# Out:
# 0    0
# Name: number_of_kids, dtype: int64

# %%
df[df['number_of_kids'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, number_of_kids]
# Index: []

# %%
df[df['gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, number_of_kids]
# Index: []

# %%
df[df['age'].any()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# ...
