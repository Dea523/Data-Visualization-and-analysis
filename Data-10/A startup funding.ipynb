# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("startup_funding.csv")

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.tail()
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039            NaN        Asia Pacific Internet Group  Private Equity
# 3040            NaN                     KARSEMVEN Fund  Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                         MakeMyTrip  Private Equity
# 3043            NaN  UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# ...

# %%
df.columns
# Out:
# Index(['Sr No', 'Date dd/mm/yyyy', 'Startup Name', 'Industry Vertical',
#        'SubVertical', 'City  Location', 'Investors Name', 'InvestmentnType',
#        'Amount in USD', 'Remarks'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       Sr No  Date dd/mm/yyyy  Startup Name  Industry Vertical  SubVertical  \
# 0     False            False         False              False        False
# 1     False            False         False              False        False
# 2     False            False         False              False        False
# 3     False            False         False              False        False
# 4     False            False         False              False        False
# ...     ...              ...           ...                ...          ...
# 3039  False            False         False               True         True
# 3040  False            False         False               True         True
# 3041  False            False         False               True         True
# 3042  False            False         False               True         True
# 3043  False            False         False               True         True
#
# ...

# %%
df.describe()
# Out:
#              Sr No
# count  3044.000000
# mean   1522.500000
# std     878.871435
# min       1.000000
# 25%     761.750000
# 50%    1522.500000
# 75%    2283.250000
# max    3044.000000

# %%
df.isnull().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
df.shape
# Out:
# (3044, 10)

# %%
df["Amount in USD"].unique()
# Out:
# array(['20,00,00,000', '80,48,394', '1,83,58,860', '30,00,000',
#        '18,00,000', '90,00,000', '15,00,00,000', '60,00,000',
#        '7,00,00,000', '5,00,00,000', '2,00,00,000', '1,20,00,000',
#        '3,00,00,000', '59,00,000', '20,00,000', '23,10,00,000',
#        '4,86,000', '15,00,000', 'undisclosed', '2,60,00,000',
#        '1,74,11,265', '13,00,000', '13,50,00,000', '3,00,000',
#        '22,00,00,000', '1,58,00,000', '28,30,00,000', '1,00,00,00,000',
#        '4,50,00,000', '58,50,00,000', 'unknown', '45,00,000', '33,00,000',
#        '50,00,000', '1,80,00,000', '10,00,000', '1,00,00,000',
#        '45,00,00,000', '16,00,000', '14,00,00,000', '3,80,80,000',
#        '12,50,00,000', '1,10,00,000', '5,10,00,000', '3,70,00,000',
#        '5,00,000', '11,00,00,000', '1,50,00,000', '65,90,000',
#        'Undisclosed', '3,90,00,00,000', '1,90,00,000', '25,00,000',
#        '1,45,000', '6,00,00,000', '1,60,00,000', '57,50,000', '3,19,605',
# ...

# %%
df["Amount in USD"].nunique()
# Out:
# 471

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df4=df.groupby("InvestmentnType")

# %%
df4.head()
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 2936   2937      02/02/2015                    Dealwithus
# 2937   2938      02/02/2015                  CleverSharks
# 2997   2998      06/01/2015                     Tookitaki
# 3000   3001      07/01/2015                      Nurturey
# 3002   3003      07/01/2015                   Stridalyzer
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
df.InvestmentnType.value_counts()
# Out:
# Private Equity                 1356
# Seed Funding                   1355
# Seed/ Angel Funding              60
# Seed / Angel Funding             47
# Seed\\nFunding                   30
# Debt Funding                     25
# Series A                         24
# Seed/Angel Funding               23
# Series B                         20
# Series C                         14
# Series D                         12
# Angel / Seed Funding              8
# Seed Round                        7
# Pre-Series A                      4
# Private Equity Round              4
# Seed                              4
# Seed / Angle Funding              3
# pre-Series A                      2
# Venture Round                     2
# Equity                            2
# Corporate Round                   2
# Series E                          2
# Series F                          2
# Private                           1
# Debt-Funding                      1
# Term Loan                         1
# ...

# %%
df.columns=['SNo', 'Date', 'StartupName', 'IndustryVertical', 'SubVertical',
       'CityLocation', 'InvestorsName', 'InvestmentType', 'AmountInUSD',
       'Remarks']

# %%
# As we can see, Remarks column has the 86.235217% missing value, so we will drop it.
df.drop("Remarks", axis=1, inplace=True)

# %%
df.head()
# Out:
#    SNo        Date                   StartupName     IndustryVertical  \
# 0    1  09/01/2020                        BYJU’S               E-Tech
# 1    2  13/01/2020                        Shuttl       Transportation
# 2    3  09/01/2020                     Mamaearth           E-commerce
# 3    4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4    5  02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical CityLocation  \
# 0                             E-learning    Bengaluru
# 1              App based shuttle service      Gurgaon
# 2  Retailer of baby and toddler products    Bengaluru
# 3                      Online Investment    New Delhi
# 4            Embroiled Clothes For Women       Mumbai
#
#                InvestorsName        InvestmentType   AmountInUSD
# 0    Tiger Global Management  Private Equity Round  20,00,00,000
# 1  Susquehanna Growth Equity              Series C     80,48,394
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3039    False
# 3040    False
# 3041    False
# 3042    False
# 3043    False
# Length: 3044, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.CityLocation.value_counts().sort_values(ascending=False).head(10)
# Out:
# Bangalore    700
# Mumbai       567
# New Delhi    421
# Gurgaon      287
# Bengaluru    141
# Pune         105
# Hyderabad     99
# Chennai       97
# Noida         92
# Gurugram      50
# Name: CityLocation, dtype: int64

# %%
plt.plot(df.InvestorsName.value_counts().head())
plt.xticks(rotation=90)
plt.show()

# %%
df.InvestmentType.value_counts().sort_values(ascending=False).head(10)
# Out:
# Private Equity          1356
# Seed Funding            1355
# Seed/ Angel Funding       60
# Seed / Angel Funding      47
# Seed\\nFunding            30
# Debt Funding              25
# Series A                  24
# Seed/Angel Funding        23
# Series B                  20
# Series C                  14
# Name: InvestmentType, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.plot(df.InvestmentType.value_counts().head())
plt.xticks(rotation=90)
plt.show()

# %%
df.AmountInUSD.value_counts().sort_values(ascending=False).head(10)
# Out:
# 10,00,000      165
# 5,00,000       108
# 20,00,000       69
# 50,00,000       66
# 30,00,000       66
# 1,00,00,000     60
# 1,00,000        57
# 1,50,000        45
# 2,00,000        44
# 2,50,000        41
# Name: AmountInUSD, dtype: int64

# %%
df.StartupName.groupby(df.AmountInUSD).sum().head()
# Out:
# AmountInUSD
# 1,00,00,00,000                                                Paytm
# 1,00,00,000       Atomberg TechnologyBira91MakeMyTripCoinTribeVe...
# 1,00,000          Toppr3HCareFincashMergerWareFrapperzMedinfiBad...
# 1,000,000,                                                Pipabella
# 1,01,00,000                                                 eshakti
# Name: StartupName, dtype: object

# %%
df = InvestmentType_df.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df = InvestmentType_df.copy()
#
# NameError: name 'InvestmentType_df' is not defined

# %%
df['InvestmentType'].nunique()
# Out:
# 55

# %%
df['InvestmentType'].unique()
# Out:
# array(['Private Equity Round', 'Series C', 'Series B', 'Pre-series A',
#        'Seed Round', 'Series A', 'Series D', 'Seed', 'Series F',
#        'Series E', 'Debt Funding', 'Series G', 'Series H', 'Venture',
#        'Seed Funding', nan, 'Funding Round', 'Corporate Round',
#        'Maiden Round', 'pre-series A', 'Seed Funding Round',
#        'Single Venture', 'Venture Round', 'Pre-Series A', 'Angel',
#        'Series J', 'Angel Round', 'pre-Series A',
#        'Venture - Series Unknown', 'Bridge Round', 'Private Equity',
#        'Debt and Preference capital', 'Inhouse Funding',
#        'Seed/ Angel Funding', 'Debt', 'Pre Series A', 'Equity',
#        'Debt-Funding', 'Mezzanine', 'Series B (Extension)',
#        'Equity Based Funding', 'Private Funding', 'Seed / Angel Funding',
#        'Seed/Angel Funding', 'Seed funding', 'Seed / Angle Funding',
#        'Angel / Seed Funding', 'Private', 'Structured Debt', 'Term Loan',
# ...

# %%
sum(df['SubVertical'].str.len() != 10)
# Out:
# 3034

# %%
df[df['SubVertical'].str.len() > 10]
# Out:
#        SNo        Date                   StartupName     IndustryVertical  \
# 1        2  13/01/2020                        Shuttl       Transportation
# 2        3  09/01/2020                     Mamaearth           E-commerce
# 3        4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4        5  02/01/2020                        Fashor  Fashion and Apparel
# 5        6  13/01/2020                         Pando            Logistics
# ...    ...         ...                           ...                  ...
# 2103  2104  29/01/2016                    Rare Media           Technology
# 2104  2105  29/01/2016                        TinMen    Consumer Internet
# 2105  2106  29/01/2016                    CodingLabs           Technology
# 2106  2107  30/01/2016                   FindUrClass    Consumer Internet
# 2107  2108  30/01/2016                    DesignBids    Consumer Internet
#
#                                    SubVertical CityLocation  \
# ...

# %%
df['StartupName'].sort_values(ascending=True)
# Out:
# 67             "BYJU\\'S"
# 2992                #Fame
# 1242            121Policy
# 201             19th mile
# 1007               1Crowd
#               ...
# 1198              vImmune
# 1845    vPhrase Analytics
# 2902               wWhere
# 728            wayForward
# 194              zippserv
# Name: StartupName, Length: 3044, dtype: object

# %%
display(df["AmountInUSD"][0])
display(df["AmountInUSD"][0]*2)
# Out:
# '20,00,00,000'
# '20,00,00,00020,00,00,000'

# %%
i=df['InvestorsName'].value_counts().head(11).reset_index()
i.columns=["InvestorsName", "Number"]
i.head(2)
# Out:
#            InvestorsName  Number
# 0  Undisclosed Investors      39
# 1  Undisclosed investors      30

# %%
start=df.dropna()

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
px.histogram(start, x="InvestorsName")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
# ...

# %%
##Lets check the startups who has recieved bottom 20 minor fundings

start=df.sort_values(by=["AmountInUSD"],ascending=True).reset_index()

# %%
start_botfun=df[0:20]

# %%
start_botfun[["StartupName","AmountInUSD"]]
# Out:
#                      StartupName   AmountInUSD
# 0                         BYJU’S  20,00,00,000
# 1                         Shuttl     80,48,394
# 2                      Mamaearth   1,83,58,860
# 3   https://www.wealthbucket.in/     30,00,000
# 4                         Fashor     18,00,000
# 5                          Pando     90,00,000
# 6                         Zomato  15,00,00,000
# 7                         Ecozen     60,00,000
# 8                       CarDekho   7,00,00,000
# 9                   Dhruva Space   5,00,00,000
# 10                        Rivigo   2,00,00,000
# 11                    Healthians   1,20,00,000
# 12                       Licious   3,00,00,000
# 13                        InCred     59,00,000
# 14                         Trell     20,00,000
# 15                    Rein Games   5,00,00,000
# 16                  Lenskart.com  23,10,00,000
# 17                    Freshworks  15,00,00,000
# 18                       Misters      4,86,000
# ...

# %%
plt.figure(figsize=(15,8))
sns.set(style="darkgrid")
sns.barplot(data=start_botfun,y="StartupName",x="AmountInUSD",palette="ch:s=.25,rot=-.25")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [66], line 3
#       1 plt.figure(figsize=(15,8))
#       2 sns.set(style="darkgrid")
# ----> 3 sns.barplot(data=start_botfun,y="StartupName",x="AmountInUSD",palette="ch:s=.25,rot=-.25")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\seaborn\categorical.py:2754, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2751 if estimator is len:
#    2752     estimator = "size"
# -> 2754 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2755                       estimator, errorbar, n_boot, units, seed,
#    2756                       orient, color, palette, saturation,
#    2757                       width, errcolor, errwidth, capsize, dodge)
#    2759 if ax is None:
# ...

# %%
start_INtype=start["StartupName"].value_counts()[0:20].reset_index()

# %%
start_INtype
# Out:
#             index  StartupName
# 0        Ola Cabs            8
# 1          Swiggy            8
# 2           Paytm            7
# 3         Medinfi            6
# 4           Nykaa            6
# 5        NoBroker            6
# 6       UrbanClap            6
# 7          Meesho            6
# 8   Capital Float            5
# 9        Flipkart            5
# 10        Grofers            5
# 11         Moglix            5
# 12       Uniphore            5
# 13         Jugnoo            5
# 14          Toppr            5
# 15      BigBasket            4
# 16       CarDekho            4
# 17       Magicpin            4
# 18          Zoctr            4
# 19            Ola            4
