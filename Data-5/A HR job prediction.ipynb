# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("HR job analytic prediction.csv")

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
df.tail()
# Out:
#       enrollee_id      city  city_development_index gender  \
# 2124         1289  city_103                   0.920   Male
# 2125          195  city_136                   0.897   Male
# 2126        31762  city_100                   0.887   Male
# 2127         7873  city_102                   0.804   Male
# 2128        12215  city_102                   0.804   Male
#
#           relevent_experience enrolled_university education_level  \
# 2124   No relevent experience       no_enrollment        Graduate
# 2125  Has relevent experience       no_enrollment         Masters
# 2126   No relevent experience       no_enrollment  Primary School
# 2127  Has relevent experience    Full time course     High School
# 2128  Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size   company_type last_new_job  \
# 2124       Humanities         16          NaN  Public Sector            4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %%
df.isnull()
# Out:
#       enrollee_id   city  city_development_index  gender  relevent_experience  \
# 0           False  False                   False   False                False
# 1           False  False                   False   False                False
# 2           False  False                   False   False                False
# 3           False  False                   False   False                False
# 4           False  False                   False   False                False
# ...           ...    ...                     ...     ...                  ...
# 2124        False  False                   False   False                False
# 2125        False  False                   False   False                False
# 2126        False  False                   False   False                False
# 2127        False  False                   False   False                False
# 2128        False  False                   False   False                False
#
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# company_size              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours
# count   2129.000000             2129.000000     2129.000000
# mean   16861.614843                0.824984       64.983091
# std     9576.846029                0.125074       60.238660
# min        3.000000                0.448000        1.000000
# 25%     8562.000000                0.698000       23.000000
# 50%    16816.000000                0.903000       47.000000
# 75%    25129.000000                0.920000       86.000000
# max    33353.000000                0.949000      334.000000

# %%
df.nunique()
# Out:
# enrollee_id               2129
# city                       108
# city_development_index      81
# gender                       3
# relevent_experience          2
# enrolled_university          3
# education_level              5
# major_discipline             6
# experience                  22
# company_size                 8
# company_type                 6
# last_new_job                 6
# training_hours             223
# dtype: int64

# %%
px.pie(df, names='gender', title='gender')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
# ...

# %%
sns.boxplot( data=df, x='training_hours', y='gender')
# Out:
# <AxesSubplot: xlabel='training_hours', ylabel='gender'>

# %%
sns.pairplot(df, hue='city')

# %%
sns.pairplot(df, hue='relevent_experience')

# %%
sns.pairplot(df, hue='major_discipline')

# %%
sns.pairplot(df, hue='company_type')

# %%
sns.pairplot(df, hue='last_new_job')

# %%
sns.pairplot(df,hue='training_hours')

# %%
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
sns.scatterplot(data=df, x='gender', y='education_level')
# Out:
# <AxesSubplot: xlabel='gender', ylabel='education_level'>

# %%
sns.scatterplot(data=df, x='company_type', y='enrolled_university')
# Out:
# <AxesSubplot: xlabel='company_type', ylabel='enrolled_university'>

# %%
df['education_level'].value_counts(normalize=True) * 100
# Out:
# Graduate          61.097737
# Masters           23.880597
# High School       10.688493
# Phd                2.599904
# Primary School     1.733269
# Name: education_level, dtype: float64

# %%
df['company_type'].value_counts(normalize=True) * 100
# Out:
# Pvt Ltd                76.321070
# Public Sector           8.494983
# Funded Startup          6.488294
# Early Stage Startup     4.347826
# NGO                     3.545151
# Other                   0.802676
# Name: company_type, dtype: float64

# %%
df.shape
# Out:
# (2129, 13)

# %%
df.sample()
# Out:
#      enrollee_id     city  city_development_index gender  \
# 146         3587  city_16                    0.91   Male
#
#          relevent_experience enrolled_university education_level  \
# 146  Has relevent experience       no_enrollment         Masters
#
#     major_discipline experience company_size company_type last_new_job  \
# 146       Humanities          7          NaN      Pvt Ltd            4
#
#      training_hours
# 146              21

# %%
df.sample(5)
# Out:
#       enrollee_id      city  city_development_index gender  \
# 2071        30903  city_103                   0.920   Male
# 374          1456  city_103                   0.920   Male
# 1111        32766  city_103                   0.920   Male
# 798          5943   city_61                   0.913   Male
# 950         25612   city_71                   0.884   Male
#
#           relevent_experience enrolled_university education_level  \
# 2071  Has relevent experience       no_enrollment        Graduate
# 374   Has relevent experience       no_enrollment        Graduate
# 1111  Has relevent experience       no_enrollment        Graduate
# 798   Has relevent experience       no_enrollment             Phd
# 950   Has relevent experience       no_enrollment         Masters
#
#      major_discipline experience company_size    company_type last_new_job  \
# 2071       Humanities        >20        50-99         Pvt Ltd           >4
# ...
