# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv("vaccination_data.csv")

# %%
data
# Out:
#                                        State  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar         7541       4        7408
# 1                             Andhra Pradesh      1978350   20593     1944267
# 2                          Arunachal Pradesh        49668    3032       46399
# 3                                      Assam       572546   11719      555470
# 4                                      Bihar       725122     357      715119
# 5                                 Chandigarh        61970      27       61132
# 6                               Chhattisgarh      1002958    1780      987642
# 7   Dadra And Nagar Haveli And Daman And Diu        10652      12       10636
# 8                                      Delhi      1436623     516     1411042
# 9                                        Goa       171705     992      167556
# 10                                   Gujarat       825001     204      814720
# ...

# %%
data.head()
# Out:
#                  State  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman And Nicobar         7541       4        7408     129
# 1       Andhra Pradesh      1978350   20593     1944267   13490
# 2    Arunachal Pradesh        49668    3032       46399     237
# 3                Assam       572546   11719      555470    5357
# 4                Bihar       725122     357      715119    9646
#
#    Total vaccination doses    Dose 1   Dose 2
# 0                   308179    214334    93845
# 1                 23390769  17319963  6070806
# 2                   868372    685988   182384
# 3                 12089630   9977914  2111716
# 4                 26796305  22501851  4294454

# %%
data.tail()
# Out:
#             State  Total Cases  Active  Discharged  Deaths  \
# 31      Telengana       648388    8674      635895    3819
# 32        Tripura        79948    2515       76667     766
# 33  Uttar Pradesh      1708689     619     1685299   22771
# 34    Uttarakhand       342336     513      334456    7367
# 35    West Bengal      1532379   10642     1503535   18202
#
#     Total vaccination doses    Dose 1   Dose 2
# 31                 15377071  11548293  3828778
# 32                  3200186   2402133   798053
# 33                 53295533  44974649  8320884
# 34                  6424330   4882205  1542125
# 35                 31775426  22747208  9028218

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    36 non-null     object
#  1   Total Cases              36 non-null     int64
#  2   Active                   36 non-null     int64
#  3   Discharged               36 non-null     int64
#  4   Deaths                   36 non-null     int64
#  5   Total vaccination doses  36 non-null     int64
#  6   Dose 1                   36 non-null     int64
#  7   Dose 2                   36 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.4+ KB

# %%
data.isnull()
# Out:
#     State  Total Cases  Active  Discharged  Deaths  Total vaccination doses  \
# 0   False        False   False       False   False                    False
# 1   False        False   False       False   False                    False
# 2   False        False   False       False   False                    False
# 3   False        False   False       False   False                    False
# 4   False        False   False       False   False                    False
# 5   False        False   False       False   False                    False
# 6   False        False   False       False   False                    False
# 7   False        False   False       False   False                    False
# 8   False        False   False       False   False                    False
# 9   False        False   False       False   False                    False
# 10  False        False   False       False   False                    False
# ...

# %%
data.isnull().any()
# Out:
# State                      False
# Total Cases                False
# Active                     False
# Discharged                 False
# Deaths                     False
# Total vaccination doses    False
# Dose 1                     False
# Dose 2                     False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# State                      0
# Total Cases                0
# Active                     0
# Discharged                 0
# Deaths                     0
# Total vaccination doses    0
# Dose 1                     0
# Dose 2                     0
# dtype: int64

# %%
data.shape
# Out:
# (36, 8)

# %%
data.columns
# Out:
# Index(['State', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Total vaccination doses', 'Dose 1', 'Dose 2'],
#       dtype='object')

# %%
data['Deaths'].mode()
# Out:
# 0          4
# 1         50
# 2        129
# 3        161
# 4        207
# 5        237
# 6        352
# 7        582
# 8        766
# 9        811
# 10      1147
# 11      1628
# 12      1799
# 13      3157
# 14      3533
# 15      3819
# 16      4386
# 17      5130
# 18      5357
# 19      6302
# 20      7367
# 21      8954
# 22      9646
# 23      9647
# 24     10077
# 25     10514
# 26     13490
# 27     13536
# 28     16312
# 29     17515
# 30     18202
# 31     22771
# 32     25065
# 33     34260
# 34     36741
# 35    133717
# Name: Deaths, dtype: int64

# %%
data[data['Deaths'].isnull()]
# Out:
# Empty DataFrame
# Columns: [State, Total Cases, Active, Discharged, Deaths, Total vaccination doses, Dose 1, Dose 2]
# Index: []

# %%
data.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000
# mean   8.859829e+05   11448.694444  8.626628e+05   11871.416667
# std    1.282199e+06   31839.162320  1.239847e+06   22952.890569
# min    7.541000e+03       4.000000  7.408000e+03       4.000000
# 25%    6.657275e+04     326.000000  6.136675e+04     799.750000
# 50%    4.599410e+05    1387.000000  4.487250e+05    5243.500000
# 75%    9.892878e+05    9166.000000  9.721065e+05   13501.500000
# max    6.341759e+06  178722.000000  6.130137e+06  133717.000000
#
#        Total vaccination doses        Dose 1        Dose 2
# count             3.600000e+01  3.600000e+01  3.600000e+01
# mean              1.382116e+07  1.075671e+07  3.064444e+06
# std               1.475343e+07  1.167673e+07  3.254998e+06
# min               6.749100e+04  5.077200e+04  1.671900e+04
# 25%               8.866900e+05  6.844645e+05  2.106880e+05
# ...

# %%
print(data.nunique())
# Out:
# State                      36
# Total Cases                36
# Active                     36
# Discharged                 36
# Deaths                     36
# Total vaccination doses    36
# Dose 1                     36
# Dose 2                     36
# dtype: int64

# %%
print(data['Total vaccination doses'].unique())
# Out:
# [  308179 23390769   868372 12089630 26796305   892796 12448461   653551
#  10559677  1370190 35631476 12654504  5502831  6603777 10094104 32350283
#  21560622   257551    67491 34238893 46376886  1379355  1149142   855488
#    785513 17714962   741733 10057356 34620726   647540 24821006 15377071
#   3200186 53295533  6424330 31775426]
