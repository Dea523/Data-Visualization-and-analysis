# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("Loan payments data.csv")

# %%
df
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
df.tail()
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
df.describe()
# Out:
#          Principal       terms  past_due_days         age
# count   500.000000  500.000000      200.00000  500.000000
# mean    943.200000   22.824000       36.01000   31.116000
# std     115.240274    8.000064       29.38088    6.084784
# min     300.000000    7.000000        1.00000   18.000000
# 25%    1000.000000   15.000000        3.00000   27.000000
# 50%    1000.000000   30.000000       37.00000   30.000000
# 75%    1000.000000   30.000000       60.00000   35.000000
# max    1000.000000   30.000000       76.00000   51.000000

# %%
df = df.isnull().any();
df
# Out:
# False

# %%
df.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Loan_ID           False
# loan_status       False
# Principal         False
# terms             False
# effective_date    False
# due_date          False
# paid_off_time      True
# past_due_days      True
# age               False
# education         False
# Gender            False
# dtype: bool

# %%
df.shape
# Out:
# (500, 11)

# %%
df.sample()
# Out:
#          Loan_ID loan_status  Principal  terms effective_date    due_date  \
# 262  xqd20160263     PAIDOFF        800     30      9/13/2016  10/12/2016
#
#        paid_off_time  past_due_days  age education  Gender
# 262  10/11/2016 0:29            NaN   23   college  female

# %%
df.nunique()
# Out:
# Loan_ID           500
# loan_status         3
# Principal           6
# terms               3
# effective_date      7
# due_date           25
# paid_off_time     320
# past_due_days      33
# age                33
# education           4
# Gender              2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'loan_status', 'Principal', 'terms', 'effective_date',
#        'due_date', 'paid_off_time', 'past_due_days', 'age', 'education',
#        'Gender'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 221  xqd20160222             PAIDOFF       1000     30      9/12/2016
# 359  xqd20160360          COLLECTION       1000     30      9/11/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 355  xqd20160356          COLLECTION       1000     15      9/11/2016
# 479  xqd20160480  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 440  xqd20160441  COLLECTION_PAIDOFF       1000     30      9/11/2016
# 19   xqd20160020             PAIDOFF        800     30      9/10/2016
# 123  xqd20160124             PAIDOFF       1000     15      9/11/2016
# 56   xqd20160057             PAIDOFF       1000     30      9/11/2016
# 112  xqd20160113             PAIDOFF       1000     30      9/11/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 221  10/11/2016   10/11/2016 9:01            NaN   39               college
# ...

# %%
df['Loan_ID'].value_counts(normalize=True) * 100
# Out:
# xqd20166231    0.2
# xqd20160330    0.2
# xqd20160343    0.2
# xqd20160342    0.2
# xqd20160341    0.2
#               ...
# xqd20160162    0.2
# xqd20160161    0.2
# xqd20160160    0.2
# xqd12160159    0.2
# xqd20160500    0.2
# Name: Loan_ID, Length: 500, dtype: float64

# %%
df['loan_status'].value_counts(normalize=True) * 100
# Out:
# PAIDOFF               60.0
# COLLECTION            20.0
# COLLECTION_PAIDOFF    20.0
# Name: loan_status, dtype: float64

# %%
sns.boxplot( data=df, x='loan_status', y='Principal')
# Out:
# <AxesSubplot: xlabel='loan_status', ylabel='Principal'>

# %%
sns.boxplot( data=df, x='terms', y='age')
# Out:
# <AxesSubplot: xlabel='terms', ylabel='age'>

# %%
sns.pairplot(df, hue='age')

# %%
sns.pairplot(df, hue='Gender')

# %%
sns.pairplot(df, hue='effective_date')

# %%
df[df['due_date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, loan_status, Principal, terms, effective_date, due_date, paid_off_time, past_due_days, age, education, Gender]
# Index: []

# %%
y = np.arange(0.00001, 3, 0.01)
x = np.power(10, y)

# %%
fig, ax = plt.subplots()
plt.plot(x, y, 'b')
ax.tick_params(labelsize=14)
ax.set_xlabel('x', fontsize=14)
ax.set_ylabel('log10(x)', fontsize=14)
# Out:
# Text(0, 0.5, 'log10(x)')
