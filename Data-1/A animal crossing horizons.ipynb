# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("animal_crossing_data.csv")

# %%
df
# Out:
#                      Name   Variation DIY   Buy  Sell Color 1   Color 2 Size  \
# 0              3D glasses       White  No   490   122   White  Colorful  1x1
# 1              3D glasses       Black  No   490   122   Black  Colorful  1x1
# 2                 bandage       Beige  No   140    35   Beige     White  1x1
# 3                    beak      Yellow  No   490   122  Yellow    Yellow  1x1
# 4         birthday shades      Yellow  No   NFS   620  Yellow       Red  1x1
# ..                    ...         ...  ..   ...   ...     ...       ...  ...
# 217       triangle shades       Green  No   880   220   Green    Purple  1x1
# 218       triangle shades       White  No   880   220   White    Purple  1x1
# 219       triangle shades       Black  No   880   220   Black    Purple  1x1
# 220  wooden-frame glasses       Brown  No  1560   390   Brown      Gray  1x1
# 221  wooden-frame glasses  Dark brown  No  1560   390   Brown    Yellow  1x1
#
# ...

# %%
df.head(3)
# Out:
#          Name Variation DIY  Buy  Sell Color 1   Color 2 Size  Miles Price  \
# 0  3D glasses     White  No  490   122   White  Colorful  1x1          NaN
# 1  3D glasses     Black  No  490   122   Black  Colorful  1x1          NaN
# 2     bandage     Beige  No  140    35   Beige     White  1x1          NaN
#
#          Source  ... Mannequin Piece Version   Style  \
# 0  Able Sisters  ...              No   1.0.0  Active
# 1  Able Sisters  ...              No   1.0.0  Active
# 2  Able Sisters  ...             Yes   1.0.0  Active
#
#                Label Themes            Type Villager Equippable   Catalog  \
# 0                     party    AccessoryEye                 Yes  For sale
# 1                     party    AccessoryEye                 Yes  For sale
# 2  outdoorsy; comfy; sporty  AccessoryMouth                  No  For sale
#
#                     Filename Internal ID    Unique Entry ID
# 0      AccessoryGlassThreed0        4463  FNxEraBTeWRiCvtFu
# ...

# %%
df.tail()
# Out:
#                      Name   Variation DIY   Buy  Sell Color 1 Color 2 Size  \
# 217       triangle shades       Green  No   880   220   Green  Purple  1x1
# 218       triangle shades       White  No   880   220   White  Purple  1x1
# 219       triangle shades       Black  No   880   220   Black  Purple  1x1
# 220  wooden-frame glasses       Brown  No  1560   390   Brown    Gray  1x1
# 221  wooden-frame glasses  Dark brown  No  1560   390   Brown  Yellow  1x1
#
#      Miles Price        Source  ... Mannequin Piece Version   Style  \
# 217          NaN  Able Sisters  ...              No   1.0.0    Cute
# 218          NaN  Able Sisters  ...              No   1.0.0    Cute
# 219          NaN  Able Sisters  ...              No   1.0.0    Cute
# 220          NaN  Able Sisters  ...             Yes   1.0.0  Simple
# 221          NaN  Able Sisters  ...             Yes   1.0.0  Simple
#
#                Label Themes          Type Villager Equippable   Catalog  \
# ...

# %%
df.shape
# Out:
# (222, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   222 non-null    object
#  1   Variation              222 non-null    object
#  2   DIY                    222 non-null    object
#  3   Buy                    222 non-null    object
#  4   Sell                   222 non-null    int64
#  5   Color 1                222 non-null    object
#  6   Color 2                222 non-null    object
#  7   Size                   222 non-null    object
#  8   Miles Price            1 non-null      float64
#  9   Source                 222 non-null    object
#  10  Source Notes           206 non-null    object
#  11  Seasonal Availability  222 non-null    object
#  12  Mannequin Piece        222 non-null    object
#  13  Version                222 non-null    object
# ...

# %%
df.describe()
# Out:
#               Sell  Miles Price   Internal ID
# count   222.000000          1.0    222.000000
# mean    268.698198        400.0   9182.310811
# std     187.800688          NaN   3057.912627
# min      10.000000        400.0   2298.000000
# 25%     144.250000        400.0   4684.250000
# 50%     245.000000        400.0  11075.500000
# 75%     325.000000        400.0  11204.750000
# max    2000.000000        400.0  12129.000000

# %%
df.columns
# Out:
# Index(['Name', 'Variation', 'DIY', 'Buy', 'Sell', 'Color 1', 'Color 2', 'Size',
#        'Miles Price', 'Source', 'Source Notes', 'Seasonal Availability',
#        'Mannequin Piece', 'Version', 'Style', 'Label Themes', 'Type',
#        'Villager Equippable', 'Catalog', 'Filename', 'Internal ID',
#        'Unique Entry ID'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       Name  Variation    DIY    Buy   Sell  Color 1  Color 2   Size  \
# 0    False      False  False  False  False    False    False  False
# 1    False      False  False  False  False    False    False  False
# 2    False      False  False  False  False    False    False  False
# 3    False      False  False  False  False    False    False  False
# 4    False      False  False  False  False    False    False  False
# ..     ...        ...    ...    ...    ...      ...      ...    ...
# 217  False      False  False  False  False    False    False  False
# 218  False      False  False  False  False    False    False  False
# 219  False      False  False  False  False    False    False  False
# 220  False      False  False  False  False    False    False  False
# 221  False      False  False  False  False    False    False  False
#
#      Miles Price  Source  ...  Mannequin Piece  Version  Style  Label Themes  \
# ...

# %%
df.isnull().any()
# Out:
# Name                     False
# Variation                False
# DIY                      False
# Buy                      False
# Sell                     False
# Color 1                  False
# Color 2                  False
# Size                     False
# Miles Price               True
# Source                   False
# Source Notes              True
# Seasonal Availability    False
# Mannequin Piece          False
# Version                  False
# Style                    False
# Label Themes             False
# Type                     False
# Villager Equippable      False
# Catalog                  False
# Filename                 False
# Internal ID              False
# Unique Entry ID          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Name                       0
# Variation                  0
# DIY                        0
# Buy                        0
# Sell                       0
# Color 1                    0
# Color 2                    0
# Size                       0
# Miles Price              221
# Source                     0
# Source Notes              16
# Seasonal Availability      0
# Mannequin Piece            0
# Version                    0
# Style                      0
# Label Themes               0
# Type                       0
# Villager Equippable        0
# Catalog                    0
# Filename                   0
# Internal ID                0
# Unique Entry ID            0
# dtype: int64

# %%
df['Name'].count()
# Out:
# 222

# %%
Personalities = df.Type.value_counts().plot(kind='bar', color="Pink", figsize=(12,6))
plt.xlabel("Different Personalities")
plt.ylabel("Count")
plt.show()

# %%
df['Type'].value_counts().to_frame()
# Out:
#                                 Type
# AccessoryEye                     163
# AccessoryMouth                    20
# AccessoryMouthInvisibleNose       11
# AcceEyeMouth                      10
# AccessoryEyeMouthInvisibleNose     7
# AccessoryMouthEarJaw               6
# AccessoryOneEye                    5

# %%
df['Version'].nunique()
# Out:
# 1

# %%
df.rename(columns={'Version':'user_id'}, inplace=True)

# %%
df.head()
# Out:
#               Name Variation DIY  Buy  Sell Color 1   Color 2 Size  \
# 0       3D glasses     White  No  490   122   White  Colorful  1x1
# 1       3D glasses     Black  No  490   122   Black  Colorful  1x1
# 2          bandage     Beige  No  140    35   Beige     White  1x1
# 3             beak    Yellow  No  490   122  Yellow    Yellow  1x1
# 4  birthday shades    Yellow  No  NFS   620  Yellow       Red  1x1
#
#    Miles Price        Source  ... Mannequin Piece user_id     Style  \
# 0          NaN  Able Sisters  ...              No   1.0.0    Active
# 1          NaN  Able Sisters  ...              No   1.0.0    Active
# 2          NaN  Able Sisters  ...             Yes   1.0.0    Active
# 3          NaN  Able Sisters  ...             Yes   1.0.0      Cute
# 4          NaN      Birthday  ...              No   1.0.0  Gorgeous
#
#                     Label Themes                         Type  \
# 0                          party                 AccessoryEye
# ...
